# %%
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(datetime.now())
# Out:
# 2020-09-11 09:27:20.703871

# %%
print(datetime.today())
# Out:
# 2020-09-11 09:27:12.730017

# %%
t1=datetime.now()
print(t1)
t2=datetime(2020,9,11)
print(t2)
t3=datetime(2020,9,11,9,28,30)
print(t3)
# Out:
# 2020-09-11 09:29:06.757829
# 2020-09-11 00:00:00
# 2020-09-11 09:28:30

# %%
datetime.time()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-1a794641b2e4> in <module>
# ----> 1 datetime.time()
#
# TypeError: descriptor 'time' of 'datetime.datetime' object needs an argument

# %%
ebola=pd.read_csv("country_timeseries.csv")
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
ebola['Date_dt']=pd.to_datetime(ebola['Date'])
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# Date_dt                122 non-null datetime64[ns]
# ...

# %%
df2=pd.DataFrame({'order_day':['01-01-20','01-02-20']})
df2.info()
df2['date_dt']=pd.to_datetime(df2['order_day'], format="%d-%m-%y")
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
# order_day    2 non-null object
# dtypes: object(1)
# memory usage: 144.0+ bytes
#   order_day    date_dt
# 0  01-01-20 2020-01-01
# 1  01-02-20 2020-02-01

# %%
now=datetime.now()
now
# Out:
# datetime.datetime(2020, 9, 11, 10, 11, 27, 296287)

# %%
nowDate=now.strftime("%Y-%m-%d")
nowDate
# Out:
# '2020-09-11'

# %%
now.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2020-09-11 10:11:27'

# %%
ebola=pd.read_csv("country_timeseries.csv", parse_dates=['Date'])
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null datetime64[ns]
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# ...

# %%
d1=ebola['Date']
d1
# Out:
# 0     2015-01-05
# 1     2015-01-04
# 2     2015-01-03
# 3     2015-01-02
# 4     2014-12-31
#          ...
# 117   2014-03-27
# 118   2014-03-26
# 119   2014-03-25
# 120   2014-03-24
# 121   2014-03-22
# Name: Date, Length: 122, dtype: datetime64[ns]

# %%
d1[0].year
# Out:
# 2015

# %%
ebola3=pd.read_csv("country_timeseries.csv")
ebola3.info()
ebola3['Date_dt']=pd.to_datetime(ebola3['Date'])
ebola3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.3+ KB
# ...

# %%
ebola['year']=ebola3['Date_dt'].dt.year
ebola
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola3['Date_dt'].mean()
# Out:
# Timestamp('2014-08-13 20:15:44.262295040')

# %%
first=ebola3['Date_dt'].min()
last=ebola3['Date_dt'].max()
last-first
# Out:
# Timedelta('289 days 00:00:00')

# %%
banks=pd.read_csv("banklist.csv", parse_dates=['Closing Date', 'Updated Date'])
banks
# Out:
#                                              Bank Name         City  ST  \
# 0                  Washington Federal Bank for Savings      Chicago  IL
# 1      The Farmers and Merchants State Bank of Argonia      Argonia  KS
# 2                                  Fayette County Bank   Saint Elmo  IL
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI
# 4                                       First NBC Bank  New Orleans  LA
# ..                                                 ...          ...  ..
# 550                                 Superior Bank, FSB     Hinsdale  IL
# 551                                Malta National Bank        Malta  OH
# 552                    First Alliance Bank & Trust Co.   Manchester  NH
# 553                  National State Bank of Metropolis   Metropolis  IL
# 554                                   Bank of Honolulu     Honolulu  HI
#
#       CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
# Bank Name                555 non-null object
# City                     555 non-null object
# ST                       555 non-null object
# CERT                     555 non-null int64
# Acquiring Institution    555 non-null object
# Closing Date             555 non-null datetime64[ns]
# Updated Date             555 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 30.5+ KB

# %%
banks['Closing_year']=banks['Closing Date'].dt.year

# %%
banks['Closing_quarter']=banks['Closing Date'].dt.quarter

# %%
cyq=banks.groupby(['Closing_year', 'Closing_quarter']).size()
cy=banks.groupby(['Closing_year']).size()

# %%
cyq.plot()
# Out:
# C:\Users\msi\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1182: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Closing_year,Closing_quarter'>

# %%
cy.plot()
# Out:
# <AxesSubplot:xlabel='Closing_year'>

# %%
import pandas_datareader as pdr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-59-7da9f55a5922> in <module>
# ----> 1 import pandas_datareader as pdr
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
tesla=pd.read_csv("tesla_stock_quandl.csv", parse_dates=['Date'])
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 13 columns):
# Date          1949 non-null datetime64[ns]
# Open          1949 non-null float64
# High          1949 non-null float64
# Low           1949 non-null float64
# Close         1949 non-null float64
# Volume        1949 non-null float64
# ExDividend    1949 non-null float64
# SplitRatio    1949 non-null float64
# AdjOpen       1949 non-null float64
# AdjHigh       1949 non-null float64
# AdjLow        1949 non-null float64
# AdjClose      1949 non-null float64
# AdjVolume     1949 non-null float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 198.1 KB

# %%
tesla['Date'].dt.year
# Out:
# 0       2018
# 1       2018
# 2       2018
# 3       2018
# 4       2018
#         ...
# 1944    2010
# 1945    2010
# 1946    2010
# 1947    2010
# 1948    2010
# Name: Date, Length: 1949, dtype: int64

# %%
tesla.loc[(tesla['Date'].dt.year==2010) & (tesla['Date'].dt.month==6)]
# Out:
#            Date   Open     High    Low  Close      Volume  ExDividend  \
# 1947 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0         0.0
# 1948 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0         0.0
#
#       SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 1947         1.0    25.79  30.4192   23.30     23.83  17187100.0
# 1948         1.0    19.00  25.0000   17.54     23.89  18766300.0

# %%
tesla.index=tesla['Date']
#tesla.index
tesla
# Out:
#                  Date    Open      High     Low   Close      Volume  \
# Date
# 2018-03-27 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0
# 2018-03-26 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0
# 2018-03-23 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0
# 2018-03-22 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0
# 2018-03-21 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0
# ...               ...     ...       ...     ...     ...         ...
# 2010-07-06 2010-07-06   20.00   20.0000   15.83   16.11   6866900.0
# 2010-07-02 2010-07-02   23.00   23.1000   18.71   19.20   5139800.0
# 2010-07-01 2010-07-01   25.00   25.9200   20.27   21.96   8218800.0
# 2010-06-30 2010-06-30   25.79   30.4192   23.30   23.83  17187100.0
# 2010-06-29 2010-06-29   19.00   25.0000   17.54   23.89  18766300.0
#
#             ExDividend  SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose  \
# Date
# ...

# %%
tesla['2015-06']
# Out:
#                  Date    Open    High      Low   Close     Volume  ExDividend  \
# Date
# 2015-06-30 2015-06-30  264.80  270.92  264.000  268.26  3086935.0         0.0
# 2015-06-29 2015-06-29  261.95  265.95  260.700  262.02  3478909.0         0.0
# 2015-06-26 2015-06-26  268.89  269.11  266.000  267.09  3838434.0         0.0
# 2015-06-25 2015-06-25  266.45  271.41  265.250  268.79  2849204.0         0.0
# 2015-06-24 2015-06-24  266.98  267.35  263.720  265.17  2412293.0         0.0
# 2015-06-23 2015-06-23  260.32  268.00  258.570  267.67  3870818.0         0.0
# 2015-06-22 2015-06-22  262.15  264.40  255.690  259.79  4561079.0         0.0
# 2015-06-19 2015-06-19  262.40  263.80  260.100  262.51  2463013.0         0.0
# 2015-06-18 2015-06-18  262.00  263.46  260.020  261.89  2782703.0         0.0
# 2015-06-17 2015-06-17  252.17  264.36  252.020  260.41  5512920.0         0.0
# 2015-06-16 2015-06-16  250.13  253.44  249.095  253.12  1984678.0         0.0
# ...

# %%
tesla['refDate']=tesla['Date']-tesla['Date'].min()

# %%
tesla['refDate']
# Out:
# Date
# 2018-03-27   2828 days
# 2018-03-26   2827 days
# 2018-03-23   2824 days
# 2018-03-22   2823 days
# 2018-03-21   2822 days
#                 ...
# 2010-07-06      7 days
# 2010-07-02      3 days
# 2010-07-01      2 days
# 2010-06-30      1 days
# 2010-06-29      0 days
# Name: refDate, Length: 1949, dtype: timedelta64[ns]

# %%
tesla
# Out:
#                  Date    Open      High     Low   Close      Volume  \
# Date
# 2018-03-27 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0
# 2018-03-26 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0
# 2018-03-23 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0
# 2018-03-22 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0
# 2018-03-21 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0
# ...               ...     ...       ...     ...     ...         ...
# 2010-07-06 2010-07-06   20.00   20.0000   15.83   16.11   6866900.0
# 2010-07-02 2010-07-02   23.00   23.1000   18.71   19.20   5139800.0
# 2010-07-01 2010-07-01   25.00   25.9200   20.27   21.96   8218800.0
# 2010-06-30 2010-06-30   25.79   30.4192   23.30   23.83  17187100.0
# 2010-06-29 2010-06-29   19.00   25.0000   17.54   23.89  18766300.0
#
#             ExDividend  SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose  \
# Date
# ...

# %%
tesla.index=tesla['refDate']
tesla
# Out:
#                 Date    Open      High     Low   Close      Volume  \
# refDate
# 2828 days 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0
# 2827 days 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0
# 2824 days 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0
# 2823 days 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0
# 2822 days 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0
# ...              ...     ...       ...     ...     ...         ...
# 7 days    2010-07-06   20.00   20.0000   15.83   16.11   6866900.0
# 3 days    2010-07-02   23.00   23.1000   18.71   19.20   5139800.0
# 2 days    2010-07-01   25.00   25.9200   20.27   21.96   8218800.0
# 1 days    2010-06-30   25.79   30.4192   23.30   23.83  17187100.0
# 0 days    2010-06-29   19.00   25.0000   17.54   23.89  18766300.0
#
#            ExDividend  SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose  \
# refDate
# ...

# %%
tesla.loc['2828 days']
# Out:
# Date          2018-03-27 00:00:00
# Open                          304
# High                       304.27
# Low                        277.18
# Close                      279.18
# Volume                1.36962e+07
# ExDividend                      0
# SplitRatio                      1
# AdjOpen                       304
# AdjHigh                    304.27
# AdjLow                     277.18
# AdjClose                   279.18
# AdjVolume             1.36962e+07
# refDate        2828 days 00:00:00
# Name: 2828 days 00:00:00, dtype: object

# %%
tesla[tesla['Volume']==tesla['Volume'].max()]['Date']
# Out:
# refDate
# 1050 days   2013-05-14
# Name: Date, dtype: datetime64[ns]
